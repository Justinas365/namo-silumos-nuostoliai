# %%
temp = context.io.load("preprocessed_pecius")
df = temp.query('Matavimas != "Nezinoma"')
df.head(20)
# Out:
# 2021-07-28 09:15:15,629 - kedro.io.data_catalog - INFO - Loading data from `preprocessed_pecius` (CSVDataSet)...
# C:\Users\SVEDU\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         Data Matavimas    Laikas  Lauko temperatura  lauko_temp_patikslinta  \
# 0   20210118    Pirmas  14:45:00              -11.0                   -13.0
# 1   20210118    Antras  18:00:00              -11.0                   -12.0
# 2   20210119    Pirmas  13:40:00              -11.0                   -10.0
# 3   20210119    Antras  17:14:00              -13.0                   -12.0
# 4   20210120    Pirmas  14:28:00               -7.0                    -7.0
# ...

# %%
RF_list = ["lauko_temp_patikslinta", "Delta", "Wind_mph", "Humidity_percent","Barometer_mbar", "watts", "Matavimas"]
scatter_df = df[RF_list]
# Out:
# C:\Users\SVEDU\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import seaborn as sns
sns.pairplot(scatter_df)
# Out:
# C:\Users\SVEDU\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
sns.displot(x=scatter_df["watts"], bins=9)
# Out:
# C:\Users\SVEDU\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
